# %%
from DijkstraSolver import DijkstraSolver, singleAccessibilitySolve
from BasicSolver import BasicSolver
basicSolver = BasicSolver()

walkingDistanceLimit = 700
timeDeltaLimit = 180 * 60
walkingSpeed = 1.4
isRealTime = True

# %%
startLocation = {
    "stop_lat": 39.963596, 
    "stop_lon": -83.000944
}
timestamp = 1573942335
args = {
    "timestamp": timestamp, 
    "walkingDistanceLimit": walkingDistanceLimit, 
    "timeDeltaLimit": timeDeltaLimit, 
    "walkingSpeed": walkingSpeed, 
    "isRealTime": isRealTime, 
}

solver, results = singleAccessibilitySolve(args, startLocation)
solver.visualize(results, 30)
# Out:
# ------ Retrospective Timetable Routing Running... ------
# HBox(children=(IntProgress(value=0, max=3082), HTML(value='')))
# ------ Retrospective Timetable Routing Finished... ------
# ------ Scheduled Timetable Routing Running... ------
# HBox(children=(IntProgress(value=0, max=3082), HTML(value='')))
# ------ Scheduled Timetable Routing Finished... ------
# {'HANMAIN': {'startStopID': 'HIGBROS', 'receivingStopID': 'HANMAIN', 'timeRT': 5145.000000070051, 'walkTimeRT': 1197.3967436060468, 'busTimeRT': 2998, 'waitTimeRT': 949.6032564640045, 'generatingStopIDRT': 'MAIOAKE1', 'lastTripIDRT': '680659', 'lastTripTypeRT': 'bus', 'transferCountRT': 1, 'visitTagRT': True, 'timeSC': 5084.999999984232, 'walkTimeSC': 1079.6623110613496, 'busTimeSC': 3219, 'waitTimeSC': 786.3376889228821, 'generatingStopIDSC': 'MAIOAKE1', 'lastTripIDSC': '680659', 'lastTripTypeSC': 'bus', 'transferCountSC': 1, 'visitTagSC': True, 'stop_lat': '39.956666', 'stop_lon': '-82.77903'}, 'MOUWAYW': {'startStopID': 'HIGBROS', 'receivingStopID': 'MOUWAYW', 'timeRT': 1729.904520078813, 'walkTimeRT': 829.6487884961714, 'busTimeRT': 820, 'waitTimeRT': 80.2557315826416, 'generatingStopIDRT': 'MOUWAYE', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 1, 'visitTagRT': True, 'timeSC': 2144.9999999157412, 'walkTimeSC': 505.6589426151737, 'busTimeSC': 1138, 'waitTimeSC': 501.3410573005676, 'generatingStopIDSC': 'MOUHIGW2', 'lastTripIDSC': '683503', 'lastTripTypeSC': 'bus', 'transferCountSC': 1, 'visitTagSC': True, 'stop_lat': '39.938547', 'stop_lon': '-83.062991'}, 'MOREASS': {'startStopID': 'HIGBROS', 'receivingStopID': 'MOREASS', 'timeRT': 1787.0471496725568, 'walkTimeRT': 1073.1417460585126, 'busTimeRT': 315, 'waitTimeRT': 398.9054036140442, 'generatingStopIDRT': 'EASMORE', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 0, 'visitTagRT': True, 'timeSC': 2639.0471495384745, 'walkTimeSC': 382.983692049461, 'busTimeSC': 2075, 'waitTimeSC': 181.06345748901367, 'generatingStopIDSC': 'EASMORE', 'lastTripIDSC': None, 'lastTripTypeSC': 'walk', 'transferCountSC': 0, 'visitTagSC': True, 'stop_lat': '40.048117', 'stop_lon': '-82.920331'}, 'SOUTER4': {'startStopID': 'HIGBROS', 'receivingStopID': 'SOUTER4', 'timeRT': 347.2760684394194, 'walkTimeRT': 91.2760684394194, 'busTimeRT': 211, 'waitTimeRT': 45, 'generatingStopIDRT': 'HIGTOWS', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 0, 'visitTagRT': True, 'timeSC': 461.43304656522855, 'walkTimeSC': 461.43304656522855, 'busTimeSC': 0, 'waitTimeSC': 0, 'generatingStopIDSC': 'HIGBROS', 'lastTripIDSC': None, 'lastTripTypeSC': 'walk', 'transferCountSC': 0, 'visitTagSC': True, 'stop_lat': '39.957159', 'stop_lon': '-82.999083'}, 'SOUTER7': {'startStopID': 'HIGBROS', 'receivingStopID': 'SOUTER7', 'timeRT': 380.3772803561496, 'walkTimeRT': 35.37728035614956, 'busTimeRT': 300, 'waitTimeRT': 45, 'generatingStopIDRT': 'MAIHIGE', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 0, 'visitTagRT': True, 'timeSC': 595.4749757804891, 'walkTimeSC': 308.47497578048916, 'busTimeSC': 122, 'waitTimeSC': 165, 'generatingStopIDSC': 'HIGSTAS', 'lastTripIDSC': None, 'lastTripTypeSC': 'walk', 'transferCountSC': 0, 'visitTagSC': True, 'stop_lat': '39.956582', 'stop_lon': '-82.998852'}, 'NORTER2': {'startStopID': 'HIGBROS', 'receivingStopID': 'NORTER2', 'timeRT': 262.4705860492756, 'walkTimeRT': 262.4705860492756, 'busTimeRT': 0, 'waitTimeRT': 0, 'generatingStopIDRT': 'HIGBROS', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 0, 'visitTagRT': True, 'timeSC': 262.4705860492756, 'walkTimeSC': 262.4705860492756, 'busTimeSC': 0, 'waitTimeSC': 0, 'generatingStopIDSC': 'HIGBROS', 'lastTripIDSC': None, 'lastTripTypeSC': 'walk', 'transferCountSC': 0, 'visitTagSC': True, 'stop_lat': '39.965888', 'stop_lon': '-83.002424'}, 'NORTER3': {'startStopID': 'HIGBROS', 'receivingStopID': 'NORTER3', 'timeRT': 256.2852739132708, 'walkTimeRT': 256.2852739132708, 'busTimeRT': 0, 'waitTimeRT': 0, 'generatingStopIDRT': 'HIGBROS', 'lastTripIDRT': None, 'lastTripTypeRT': 'walk', 'transferCountRT': 0, 'visitTagRT': True, 'timeSC': 256.2852739132708, 'walkTimeSC': 256.2852739132708, 'busTimeSC': 0, 'waitTimeSC': 0, 'generatingStopIDSC': 'HIGBROS', 'lastTripIDSC': None, 'lastTripTypeSC': 'walk', 'transferCountSC': 0, 'visitTagSC': True, 'stop_lat': '39.965 ...
